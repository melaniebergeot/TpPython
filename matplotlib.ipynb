# %% [markdown]
# # Tutorial Pyplot

# %% [markdown]
# matplotlib.pyplot fonctionne comme sur MATLAB.
# Permet de créer une figure , zone de tracage(plotting area)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# l'axe des abcisses s'étend de 0-3 et l'axe des y de 1-4.
# Si vous fournissez une seule liste ou un seul tableau à la commande plot (), matplotlib suppose qu'il s'agit d'une séquence de valeurs y et génère automatiquement les valeurs x pour vous.
# puisque les plages de python commence à 0 pour x c'est pas pareil que pour y.
# Les données x sont donc [0,1,2,3].
#
# plot () est une commande polyvalente, et prendra un nombre arbitraire d'arguments.
# exemple : tracer x et y

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) #x,y

# %% [markdown]
# pour chaque pair d'arg (x,y) il peut y avoir un 3 eme arg (optionnel) qui indique la couleur et le type de ligne du graphique.
# même lettre et symboles que dans MATLAB.
# le format par defaut de string est "b-" qui est une ligne bleue
# par exemple si on veut des cercles rouges :

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'r')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'c')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], 'co')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# Regarder la plot() documentation pour en savoir plus :
# https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot
#
#
# Axis() : dans l'exemple suivant on prend une liste de [xmin, xmax, ymin, ymax] et on specifie la fenetre d'affichage des axes.
#
#
# il illustre un tracé de plusieurs lignes avec différents styles de format dans une commande utilisant des tableaux.

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

#-- tiret
#s carré
#^ triangle
#** puissance

# %% [markdown]
# # Contrôle des propriétés de ligne

# %% [markdown]
# Les lignes ont de nombreux attributs que l'ont peut définir : largeur de ligne (linewidth), style de tiret (dash style), antialiased ( depixeliation)
#
# voir pour plus d'info : https://matplotlib.org/api/lines_api.html#matplotlib.lines.Line2D
#
# plusieurs manière de faire :
# mot clés args :

# %%
x=[i for i in range(5)]
y=[i for i in range(5)]
plt.plot(x, y, linewidth=1.0)

# %%
x=[i for i in range(5)]
y=[i for i in range(5)]
plt.plot(x, y, linewidth=10.0)

# %% [markdown]
# Utilisez les méthodes setter d'une instance Line2D.
# plot renvoie une liste d'objets Line2D;
#
# Par exemple, ligne1, ligne2 = tracé (x1, y1, x2, y2). Dans le code ci-dessous nous supposerons que nous n'avons qu'une seule ligne pour que la liste retournée soit de longueur 1. Nous utilisons tuple unpacking avec line, pour obtenir le premier élément de cette liste:

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False) # turn off antialising

# %% [markdown]
# Utilisation de la commande setp().
# commande de style MATLABpour définir plusieurs propriétés sur une liste de lignes.
# setp fonctionne de manière transparente avec une liste d'objets ou un seul objet.
# On peut aussi utiliser des arguments de mot-clé python u des paires de chaînes / valeurs de type MATLAB:

# %%
x1=[1.00,2.00,3.00,4.00]
y1=[1.00,2.00,3.00,4.00]
x2=[1.00,2.00,3.00,4.00]
y2=[1.00,2.00,3.00,4.00]
#[i for i in range(5)]
# use keyword args
lines = plt.plot(x1, y1, x2, y2)
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# use keyword args
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# [None, None, None, None]

# %% [markdown]
# Pour obtenir une liste des propriétés de ligne configurables, appelez la fonction setp () avec une ligne ou des lignes en argument

# %%
lines = plt.plot([1, 2, 3])

# %%
plt.setp(lines)
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float (0.0 transparent through 1.0 opaque)
#   animated: bool
#   antialiased or aa: [True | False]
#   clip_box: a `~.Bbox` instance
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `~.Transform`) | `~.Patch` | None]
#   color or c: any matplotlib color
#   contains: a callable function
#   dash_capstyle: ['butt' | 'round' | 'projecting']
#   dash_joinstyle: ['miter' | 'round' | 'bevel']
#   dashes: sequence of on/off ink in points
#   drawstyle: ['default' | 'steps' | 'steps-pre' | 'steps-mid' | 'steps-post']
#   figure: a `~.Figure` instance
#   fillstyle: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#   gid: an id string
#   label: object
#   linestyle or ls: ['solid' | 'dashed', 'dashdot', 'dotted' | (offset, on-off-dash-seq) | ``'-'`` | ``'--'`` | ``'-.'`` | ``':'`` | ``'None'`` | ``' '`` | ``''``]
# ...

# %% [markdown]
# # travailler avec differentes figueres et axes

# %% [markdown]
# Toutes les commandes de traçage s'appliquent aux axes actuels. La fonction gca () renvoie les axes actuels (une instance matplotlib.axes.Axes), et gcf () renvoie la figure courante (instance matplotlib.figure.Figure). Normalement, vous n'avez pas à vous en soucier, car tout est pris en charge dans les coulisses. Voici un script pour créer deux subplots.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# figure() est une commande optionnelle car figure(1) peut être créer par défaut. Comme subplot (111)npeut être créer par défaut si on ne spécifie pas manuellement les axes par defaut.

# %% [markdown]
# La commande subplot() specifies numrows, numcols, fignum where fignum ranges from 1 to numrows*numcols.
#
#
# The commas in the subplot command are optional if numrows*numcols<10. So subplot(211) is identical to subplot(2, 1, 1). You can create an arbitrary number of subplots and axes. If you want to place an axes manually, i.e., not on a rectangular grid, use the axes() command, which allows you to specify the location as axes([left, bottom, width, height]) where all values are in fractional (0 to 1) coordinates. See pylab_examples example code: axes_demo.py for an example of placing axes manually and pylab_examples example code: subplots_demo.py for an example with lots of subplots.
#
# You can create multiple figures by using multiple figure() calls with an increasing figure number. Of course, each figure can contain as many axes and subplots as your heart desires:

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# C:\Users\melan\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Text(0.5,1,'Easy as 1, 2, 3')

# %% [markdown]
# on nettoie la figure avec clf() et l axes avec cla().
#
# A SAVOIR: la mémoire requise pour une figure n'est pas complètement libérée jusqu'à ce que la figure soit explicitement fermée avec close ().
#
# Supprimer toutes les références à la figure, et / ou utiliser le gestionnaire de fenêtres pour quitter la fenêtre dans laquelle la figure apparaît à l'écran, ne suffit pas, car pyplot maintient les références internes jusqu'à ce que close () soit appelé.

# %% [markdown]
# ## Travailler avec du texte:

# %% [markdown]
# La commande texte() peut être utilisé pour ajouter du texte a un endroit précis.
# xlabel(),ylabel() et title() sont utilisé pour ajouter du texte
# voir l'exemple si dessous :

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# on peut modifier les propriétés  passant des arguments de mot-clé dans les fonctions de texte ou en utilisant setp ()

# %%
t = plt.xlabel('my data', fontsize=14, color='red')

# %% [markdown]
# plus de détails ici : https://matplotlib.org/users/text_props.html#text-properties

# %% [markdown]
# ## utiliser des expressions mathématiques dans du texte
#
# matplot accepte les équations TeX par exemple pour écrire l'expression : (sigma-i = 15)

# %%
plt.title(r'$\sigma_i=15$')
# Out:
# Text(0.5,1,'$\\sigma_i=15$')

# %% [markdown]
# le r après la chaine de titre est important : signifie que la chaine est une chaine brute
#
# on a pas besoin d'avoir une instalation TeX pour avoir du texte mathématique.
#
# # Annoter du texte
#
# Les utilisations de la commande basic text () ci-dessus placent le texte à une position arbitraire sur les axes.
#
# Une utilisation courante du texte est d'annoter certaines caractéristiques du tracé, et la méthode annotate () fournit une fonctionnalité d'aide pour faciliter les annotations.
# Dans une annotation, il y a deux points à considérer: l'emplacement annoté représenté par l'argument xy et l'emplacement du texte xytext. Ces deux arguments sont des tuples (x, y).

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %% [markdown]
# Dans cet exemple, xy et xytext sont en coordonnes de données.
# D'autres exemples existe comme pylab_examples: annotation_demo.py. : https://matplotlib.org/examples/pylab_examples/annotation_demo.html#pylab-examples-annotation-demo

# %% [markdown]
# ## Logarithmique et autres axes non linéaires
#
# matplotlib.pyplot prend en charge non seulement les échelles d'axes linéaires, mais aussi les échelles logarithmiques et "logit".
# Couramment utilisé si les données couvrent de nombreux ordres de grandeur.
# On change l'échelle comme ceci :
#
# plt.xscale ('log')
#
# Un exemple de quatre graphiques avec les mêmes données et différentes échelles pour l'axe y est présenté ci-dessous:

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)
